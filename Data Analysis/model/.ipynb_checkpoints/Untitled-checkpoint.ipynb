# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Divorce_Data.csv')
# Out:
# /tmp/ipykernel_9815/1601004794.py:1: DtypeWarning: Columns (16,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Divorce_Data.csv')

# %%
# Choosing unnecessary columns to be dropped 
counter = 0
for col in data.columns: 
    print(f"{col} : {counter}")
    counter += 1
# Out:
# Unnamed: 0.10 : 0
# Unnamed: 0.6 : 1
# Unnamed: 0.5 : 2
# Unnamed: 0.4 : 3
# Unnamed: 0.3 : 4
# Unnamed: 0.2 : 5
# Unnamed: 0.1 : 6
# Unnamed: 0 : 7
# تاریخ پذیرش : 8
# نوع درخواست طلاق : 9
# ایا برای طلاق یکی از زوجین وکالت نامه رسمی دارد؟ : 10
# تابعیت زوج : 11
# تابعیت زوجه : 12
# کد ملی زوج : 13
# کد ملی زوجه : 14
# کد اقامت زوج : 15
# کد اقامت زوجه : 16
# نام زوج : 17
# نام زوجه : 18
# نام خانوادگی زوج : 19
# نام خانوادگی زوجه : 20
# تاریخ تولد زوج : 21
# تاریخ تولد زوجه  : 22
# محل تولد زوج  : 23
# محل تولد زوجه  : 24
# شماره شناسنامه زوج : 25
# شماره شناسنامه زوجه : 26
# سریال شناسنامه  زوج : 27
# سریال شناسنامه زوجه : 28
# نام پدر زوج : 29
# نام پدر وزجه : 30
# تلفن همراه زوج  : 31
# تلفن همراه زوجه : 32
# نوع آدرس زوج : 33
# نوع آدرس زوجه  : 34
# نام روستا زوج : 35
# نام روستا زوجه : 36
# آدرس زوج : 37
# آدرس زوجه : 38
# تحصیلات زوج  : 39
# تحصیلات زوجه : 40
# وضعیت محل سکونت زوج : 41
# وضعیت محل سکونت زوجه : 42
# تلفن ثابت زوج : 43
# تلفن ثابت زوجه : 44
# ...

# %%
unnecesary_columns = data.columns[[0, 1, 2, 3, 4, 5, 6, 7 ,13 , 14 ,17 , 18 , 19 , 20 , 25 , 26 , 27 , 28 , 31 , 32  ,37 ,38 ,43 ,44 , 29 ,30 ,156 , 157 ,158
                                   ]]

data.drop(unnecesary_columns, axis=1, inplace=True)

# %%
data.to_csv('Divorce_Data2.csv')
